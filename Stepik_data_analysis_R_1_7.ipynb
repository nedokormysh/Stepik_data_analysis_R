# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/Stepik_data_analysis_R/blob/week_1_data_prep/Stepik_data_analysis_R_1_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1_7_3
# Предположим, вы рассчитали стандартное отклонение вашей выборки, сохранили результат в переменную my_sd и хотите сохранить этот объект в файл "my_sd.RData".
#
# Какая команда позволит вам это сделать?

# %%
getwd()
# Out:
# [1] "/content"

# %% [markdown]
# ![image.png](data:image/png;base64,...)
